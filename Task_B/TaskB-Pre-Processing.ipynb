# %%
import pandas as pd

# %%
devd = pd.read_csv('C:/Users/Garima/OneDrive/NLP/SemEval2020-Task4-Commonsense-Validation-and-Explanation-master/ALL data/Dev Data/subtaskB_dev_data.csv', index_col = 0)
traind = pd.read_csv('C:/Users/Garima/OneDrive/NLP/SemEval2020-Task4-Commonsense-Validation-and-Explanation-master/ALL data/Training  Data/subtaskB_data_all.csv', index_col = 0)
triald = pd.read_csv('C:/Users/Garima/OneDrive/NLP/SemEval2020-Task4-Commonsense-Validation-and-Explanation-master/ALL data/Trial Data/taskB_trial_data.csv', index_col = 0)

test = pd.read_csv('C:/Users/Garima/OneDrive/NLP/SemEval2020-Task4-Commonsense-Validation-and-Explanation-master/ALL data/Test Data/subtaskB_test_data.csv')

# %%
deva = pd.read_csv('C:/Users/Garima/OneDrive/NLP/SemEval2020-Task4-Commonsense-Validation-and-Explanation-master/ALL data/Dev Data/subtaskB_gold_answers.csv', index_col = 0)
traina = pd.read_csv('C:/Users/Garima/OneDrive/NLP/SemEval2020-Task4-Commonsense-Validation-and-Explanation-master/ALL data/Training  Data/subtaskB_answers_all.csv', index_col = 0)
triala = pd.read_csv('C:/Users/Garima/OneDrive/NLP/SemEval2020-Task4-Commonsense-Validation-and-Explanation-master/ALL data/Trial Data/taskB_trial_answer.csv', index_col = 0)

# %%
traind
# Out:
#                                               FalseSent  \
# id
# 0                 He poured orange juice on his cereal.
# 1                                      He drinks apple.
# 2                          Jeff ran 100,000 miles today
# 3                                    I sting a mosquito
# 4                                A giraffe is a person.
# ...                                                 ...
# 9995                   Mark ate a big bitter cherry pie
# 9996                     Gloria wears a cat on her head
# 9997  Harry went to the barbershop to have his glass...
# 9998                   Reilly is sleeping on the window
# 9999                           I have a desk on my lamp
#
#                                                 OptionA  \
# id
# 0                Orange juice is usually bright orange.
# 1               Apple juice are very tasty and milk too
# 2     100,000 miles is way to long for one person to...
# ...

# %%
devd
# Out:
#                                               FalseSent  \
# id
# 1363  Summer in North America is great for skiing,  ...
# 392             You can use detergent to dye your hair.
# 540   passing your driving license exams requires st...
# 3                         The hangers bought the closet
# 560                             coffee depresses people
# ...                                                 ...
# 700                        THE TEMPERATURE IS EMOTIONAL
# 355                      Blended up fruit makes a nacho
# 1550                            Dogs falls from the sky
# 1364                    He put a dinosaur in the fridge
# 1257  The cleaner is in charge of the money at the s...
#
#                                                 OptionA  \
# id
# 1363  Snowmen can become violent due to their isolat...
# 392    Detergent and bleach are both cleaning products.
# 540   the driving license is useless for studying fo...
# ...

# %%
triald
# Out:
#                                               FalseSent  \
# id
# 1                    he put an elephant into the fridge
# 2      my sister eats a stone after breakfast every day
# 3                    money can be used for buying stars
# 4     USA is located in the northeastern part of New...
# 5     a man can better see stars and the moon in day...
# ...                                                 ...
# 2017                  she cleans her teeth with shampoo
# 2018                  you can see a dinosaur in the zoo
# 2019  people have to hold onto their shoes because o...
# 2020  Rebecca wakes up because she takes sleeping pills
# 2021                    people bleed when they feel hot
#
#                                                 OptionA  \
# id
# 1              an elephant is much bigger than a fridge
# 2                      stone is usually in round-shapes
# 3                no one can get stars and sell them now
# ...

# %%
test
# Out:
#        id                                          FalseSent  \
# 0    1175        He loves to stroll at the park with his bed
# 1     452      The inverter was able to power the continent.
# 2     275            The chef put extra lemons on the pizza.
# 3     869                  sugar is used to make coffee sour
# 4      50  There are beautiful planes here and there in t...
# ..    ...                                                ...
# 995  1114           If it is a sunny day, you would got wet.
# 996     8              ice hockey is a financial institution
# 997  1945  He put water without a container in the freeze...
# 998  1053            The desert has sand that you can drink.
# 999  1123             My friend runs for 2 inches every day.
#
#                                                OptionA  \
# 0    A bed is too heavy to carry with when strollin...
# 1                    An inverter is smaller than a car
# 2             Many types of lemons are to sour to eat.
# ...

# %%
deva
# Out:
#      ans
# id
# 1363   C
# 392    C
# 540    B
# 3      B
# 560    A
# ...   ..
# 700    C
# 355    B
# 1550   B
# 1364   B
# 1257   B
#
# [997 rows x 1 columns]

# %%
traina
# Out:
#      ans
# id
# 0      B
# 1      B
# 2      A
# 3      C
# 4      B
# ...   ..
# 9995   C
# 9996   B
# 9997   A
# 9998   C
# 9999   C
#
# [10000 rows x 1 columns]

# %%
triala
# Out:
#      ans
# id
# 1      A
# 2      B
# 3      A
# 4      C
# 5      A
# ...   ..
# 2017   B
# 2018   B
# 2019   B
# 2020   A
# 2021   C
#
# [2021 rows x 1 columns]

# %%
train = pd.merge(traind, traina, on='id', how='inner')
trial = pd.merge(triald, triala, on='id', how='inner')
dev = pd.merge(devd, deva, on='id', how = 'inner')

train['id'] = train.index
dev['id'] = dev.index
trial['id'] = trial.index

# %%
def func(df):  
    
    col_names=['text', 'klass']
    
    temp = pd.DataFrame()
    temp = pd.DataFrame(columns=col_names)

    for index,row in df.iterrows():
        arow={'klass':row['ans'],'text':str(row['FalseSent']+'<eol>.'+str(row['OptionA']))}
        temp = temp.append(arow, ignore_index=True)
        brow={'klass':row['ans'],'text':str(row['FalseSent']+'<eol>.'+str(row['OptionB']))}
        temp = temp.append(brow, ignore_index=True)
        crow={'klass':row['ans'],'text':str(row['FalseSent']+'<eol>.'+str(row['OptionC']))}
        temp = temp.append(crow, ignore_index=True)
        
    c='C'
    
    for index,row in temp.iterrows():
        if(c=='C'):
            c='A'
        elif(c=='A'):
            c='B'
        elif(c=='B'):
            c='C'
        if(row['klass']==c):
            temp.at[index,'klass']=1
        else:
            temp.at[index,'klass']=0
            
    return temp

# %%
train = func(train)
dev = func(dev)
trial = func(trial)

# %%
test = pd.read_csv('C:/Users/Garima/OneDrive/NLP/SemEval2020-Task4-Commonsense-Validation-and-Explanation-master/ALL data/Test Data/subtaskB_test_data.csv')


col_names=['text']
temp=pd.DataFrame(columns=col_names)

for index,row in test.iterrows():
    arow={'text':str(row['FalseSent'])+'<eol>.'+str(row['OptionA'])}
    temp = temp.append(arow, ignore_index=True)
    brow={'text':str(row['FalseSent'])+'<eol>.'+str(row['OptionB'])}
    temp = temp.append(brow, ignore_index=True)
    crow={'text':str(row['FalseSent'])+'<eol>.'+str(row['OptionC'])}
    temp = temp.append(crow, ignore_index=True)
    
test = temp
test.to_json('test.json', orient = 'records')

# %%
temp = pd.concat([train, dev, trial])

temp.to_json('train.json', orient = 'records')

# %%
import json

def confunc(l):
    for i in l:    
        with open(i, "r") as read_file:
            data = json.load(read_file)
        result = [json.dumps(record) for record in data]
        with open(i, 'w') as obj:
            for i in result:
                obj.write(i+'\n')

# %%
temp = pd.concat([train, dev])
temp.to_json('train.json', orient = 'records')
del trial['klass']
trial.to_json('test.json', orient = 'records')
confunc(['train.json', 'test.json'])
